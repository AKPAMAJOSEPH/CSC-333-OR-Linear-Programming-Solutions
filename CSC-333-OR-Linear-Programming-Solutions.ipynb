# %% [markdown]
# # NUMBER 1
# Maximizing Profit for a Factory
# A factory produces two types of products, A and B. Each unit of product A requires 2
# hours of machine time and 1 unit of raw material, while each unit of product B requires
# 3 hours of machine time and 2 units of raw material. The factory has a total of 12 hours
# of machine time and 8 units of raw material available each day.
# The profit from each unit of product A is N3, and the profit from each unit of product B
# is N4. Maximize the total profit.

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE 
            Z = 5x + 4y
SUBJECT TO

            2x + 3y ≤ 12   (Machine time constraint)
            x + 2y ≤ 8     (Raw material constraint)
            x,y ≥ 0   (Non-negativity constraints)
"""

# Define the constraints
x = np.linspace(0, 10, 400)

# Constraint 1: 2x + 3y ≤ 12 → y = (12 - 2x) / 3
y1 = (12 - 2 * x) / 3

# Constraint 2: x + 2y ≤ 8 → y = (8 - x) / 2
y2 = (8 - x) / 2

# Feasibility conditions (non-negative)
y1 = np.clip(y1, 0, None)
y2 = np.clip(y2, 0, None)

# Plot the constraints
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label=r'$2x + 3y \leq 12$')
plt.plot(x, y2, label=r'$x + 2y \leq 8$')

# Shade the feasible region
plt.fill_between(x, np.minimum(y1, y2), 0, color='red', alpha=0.3, label='Feasible Region')

# Labels and legends
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.xlabel('x (Units of Product A)')
plt.ylabel('y (Units of Product B)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.title('Graphical Method for Maximizing Profit')

# Plot the objective function (Z = 5x + 4y)
# Example level curves of the objective function
for z in [10, 20, 30]:
    y_obj = (z - 5 * x) / 4
    plt.plot(x, y_obj, linestyle='--', label=f'Z={z}')

plt.legend()
plt.show()

# %% [markdown]
# # NUMBER 2
# Minimizing Cost for a Manufacturer
# A company manufactures two types of products, X and Y, using two resources: labor
# and materials. Each unit of product X requires 1 hour of labor and 2 units of material,
# while each unit of product Y requires 2 hours of labor and 1 unit of material. The
# company has a total of 6 hours of labor and 5 units of material available.
# The cost of producing each unit of product X is N2, and the cost of producing each unit
# of product Y is N5. Minimize the total production cost.

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
MINIMIZE 
            Z = 2x + 5y
SUBJECT TO

            x + 2y ≤ 5     (Materials constraint)
            2x + y ≤ 6     (Labor constraint)
            x,y ≥ 0   (Non-negativity constraints)
"""

# Define the constraints
x = np.linspace(0, 10, 400)

# Constraint 1: x + 2y ≤ 5 → y = (5 - x) / 2
y1 = (5 - x) / 2

# Constraint 2: 2x + y ≤ 6 → y = 6 - 2x
y2 = 6 - 2 * x

# Feasibility conditions (non-negative)
y1 = np.clip(y1, 0, None)
y2 = np.clip(y2, 0, None)

# Plot the constraints
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label=r'$x + 2y \leq 5$')
plt.plot(x, y2, label=r'$2x + y \leq 6$')

# Shade the feasible region
plt.fill_between(x, np.minimum(y1, y2), 0, color='red', alpha=0.3, label='Feasible Region')

# Labels and legends
plt.xlim(0, 5)
plt.ylim(0, 5)
plt.xlabel('Units of Product X (x)')
plt.ylabel('Units of Product Y (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.title('Graphical Method for Minimizing Production Cost')

# Plot the objective function (Z = 2x + 5y)
# Example level curves of the objective function
for z in [5, 10, 15]:
    y_obj = (z - 2 * x) / 5
    plt.plot(x, y_obj, linestyle='--', label=f'Z={z}')

plt.legend()
plt.show()

# %% [markdown]
# # NUMBER 3
# A factory produces two types of products, A and B, using three resources: labor, material,
# and machine time. Each unit of product A requires 2 hours of labor, 3 units of material,
# and 1 hour of machine time. Each unit of product B requires 1 hour of labor, 2 units of
# material, and 2 hours of machine time. The company has 20 hours of labor, 30 units of
# material, and 18 hours of machine time available. The profit for each unit of product A is
# N5, and the profit for each unit of product B is N4. Maximize the total profit.

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE 
            Z = 5x + 4y
SUBJECT TO

            2x + y ≤ 20     (Labor constraint)
            3x + 2y ≤ 30    (Material constraint)
            x + 2y ≤ 18     (Machine time constraint)
            x,y ≥ 0    (Non-negativity constraints)
"""

# Define the constraints
x = np.linspace(0, 20, 400)

# Constraint 1: 2x + y ≤ 20 → y = 20 - 2x
y1 = 20 - 2 * x

# Constraint 2: 3x + 2y ≤ 30 → y = (30 - 3x) / 2
y2 = (30 - 3 * x) / 2

# Constraint 3: x + 2y ≤ 18 → y = (18 - x) / 2
y3 = (18 - x) / 2

# Feasibility conditions (non-negative)
y1 = np.clip(y1, 0, None)
y2 = np.clip(y2, 0, None)
y3 = np.clip(y3, 0, None)

# Plot the constraints
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label=r'$2x + y \leq 20$')
plt.plot(x, y2, label=r'$3x + 2y \leq 30$')
plt.plot(x, y3, label=r'$x + 2y \leq 18$')

# Shade the feasible region
plt.fill_between(x, np.minimum(np.minimum(y1, y2), y3), 0, color='red', alpha=0.3, label='Feasible Region')

# Labels and legends
plt.xlim(0, 20)
plt.ylim(0, 20)
plt.xlabel('Units of Product A (x)')
plt.ylabel('Units of Product B (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.title('Graphical Method for Maximizing Profit')

# Plot the objective function (Z = 5x + 4y)
# Example level curves of the objective function
for z in [20, 40, 60]:
    y_obj = (z - 5 * x) / 4
    plt.plot(x, y_obj, linestyle='--', label=f'Z={z}')

plt.legend()
plt.show()

# %% [markdown]
# # NUMBER 4. Maximizing Revenue from Sales
# A company sells two products, A and B, and has a limited amount of advertising budget
# and production capacity. Each unit of product A brings in N4, and each unit of product
# B brings in N5. The company has a total advertising budget of N20 and a production
# capacity of 15 units. The advertisement cost for each unit of product A is N1, and the
# advertisement cost for each unit of product B is N2. Each unit of product A requires 1
# unit of production capacity, while each unit of product B requires 2 units of production
# capacity. Maximize the total revenue.

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE 
            Z = 4x + 5y
SUBJECT TO

            x + 2y ≤ 20     (Advertising budget constraint)
            x + 2y ≤ 15     (Production capacity constraint)
            x,y ≥ 0    (Non-negativity constraints)
"""

# Defining the constraints
x = np.linspace(0, 20, 400)

# Constraint 1: x + 2y ≤ 20 → y = (20 - x) / 2
y1 = (20 - x) / 2

# Constraint 2: x + 2y ≤ 15 → y = (15 - x) / 2
y2 = (15 - x) / 2

# Feasibility conditions (non-negative)
y1 = np.clip(y1, 0, None)
y2 = np.clip(y2, 0, None)

# Plot the constraints
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label=r'$x + 2y \leq 20$ (Ad budget)')
plt.plot(x, y2, label=r'$x + 2y \leq 15$ (Production cap)')

# Shade the feasible region
plt.fill_between(x, np.minimum(y1, y2), 0, color='red', alpha=0.3, label='Feasible Region')

# Labels and legends
plt.xlim(0, 20)
plt.ylim(0, 20)
plt.xlabel('Units of Product A (x)')
plt.ylabel('Units of Product B (y)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.title('Graphical Method for Maximizing Revenue')

# Plot the objective function (Z = 4x + 5y)
# Example level curves of the objective function
for z in [20, 40, 60]:
    y_obj = (z - 4 * x) / 5
    plt.plot(x, y_obj, linestyle='--', label=f'Z={z}')

plt.legend()
plt.show()

# %% [markdown]
# # NUMBER 5: Resource Allocation for Two Projects
# A company is considering two projects, P1 and P2. Each project requires both labor
# hours and capital investment. Project P1 requires 3 labor hours and 2 units of capital,
# while project P2 requires 4 labor hours and 1 unit of capital. The company has a total of
# 12 labor hours and 6 units of capital available.
# The profit from project P1 is N8 per unit, and the profit from project P2 is N7 per unit.
# Maximize the total profit.

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE 
    Z = 8x + 7y
SUBJECT TO
    3x + 4y ≤ 12  (Labor hours)
    2x + y ≤ 6    (Capital)
    x ≥ 0, y ≥ 0  (Non-negativity)
"""

# Create values for x
x = np.linspace(0, 10, 400)

# Constraints: solving for y in terms of x
y1 = (12 - 3 * x) / 4  # From 3x + 4y ≤ 12
y2 = 6 - 2 * x         # From 2x + y ≤ 6

# Ensure y values are non-negative
y1 = np.clip(y1, 0, None)
y2 = np.clip(y2, 0, None)

# Plot constraints
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label='3x + 4y ≤ 12')
plt.plot(x, y2, label='2x + y ≤ 6')

# Shade the feasible region
plt.fill_between(x, np.minimum(y1, y2), 0, color='red', alpha=0.3, label='Feasible Region')

# Add labels, grid, and legend
plt.xlim(0, 6)
plt.ylim(0, 6)
plt.xlabel('Project P1 (x)')
plt.ylabel('Project P2 (y)')
plt.title('Feasible Region and Objective Function')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()

# Plot example levels of the objective function Z = 8x + 7y
for z in [20, 40, 60]:
    plt.plot(x, (z - 8 * x) / 7, linestyle='--', label=f'Z={z}')

plt.legend()
plt.show()

# Calculate corner points manually
corner_points = [(0, 0), (0, 3), (2, 2), (4, 0)]
profits = [8 * x + 7 * y for x, y in corner_points]

# Find the optimal point and profit
optimal_point = corner_points[np.argmax(profits)]
optimal_profit = max(profits)

print(f"Corner Points: {corner_points}")
print(f"Profits at Corner Points: {profits}")
print(f"Optimal Solution: {optimal_point} with Profit = {optimal_profit}")
# Out:
# Corner Points: [(0, 0), (0, 3), (2, 2), (4, 0)]
# Profits at Corner Points: [0, 21, 30, 32]
# Optimal Solution: (4, 0) with Profit = 32

# %% [markdown]
# # NUMBER 6. Production Planning for a Bakery
# A bakery produces two types of cakes, chocolate cakes and vanilla cakes. Each
# chocolate cake requires 1 hour of baking time and 3 units of flour, while each vanilla
# cake requires 2 hours of baking time and 2 units of flour. The bakery has a total of 8
# hours of baking time and 12 units of flour available. The bakery earns a profit of N5 for
# each chocolate cake and N3 for each vanilla cake. Maximize the total profit.

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE 
    Z = 5x + 3y
SUBJECT TO
    x + 2y ≤ 8   (Baking time)
    3x + 2y ≤ 12 (Flour)
    x ≥ 0, y ≥ 0 (Non-negativity)
"""

# Create values for x
x = np.linspace(0, 10, 400)

# Constraints: solving for y in terms of x
y1 = (8 - x) / 2        # From x + 2y ≤ 8
y2 = (12 - 3 * x) / 2   # From 3x + 2y ≤ 12

# Ensure y values are non-negative
y1 = np.clip(y1, 0, None)
y2 = np.clip(y2, 0, None)

# Plot constraints
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label='x + 2y ≤ 8')
plt.plot(x, y2, label='3x + 2y ≤ 12')

# Shade the feasible region
plt.fill_between(x, np.minimum(y1, y2), 0, color='red', alpha=0.3, label='Feasible Region')

# Add labels, grid, and legend
plt.xlim(0, 6)
plt.ylim(0, 6)
plt.xlabel('Chocolate Cakes (x)')
plt.ylabel('Vanilla Cakes (y)')
plt.title('Feasible Region and Objective Function')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()

# Objective function Z = 5x + 3y
for z in [15, 20, 25]:
    plt.plot(x, (z - 5 * x) / 3, linestyle='--', label=f'Z={z}')

plt.legend()
plt.show()

# Calculate corner points manually
corner_points = [(0, 0), (0, 4), (2, 3), (4, 0)]  # Intersections and boundary points
profits = [5 * x + 3 * y for x, y in corner_points]

# Find the optimal point and profit
optimal_point = corner_points[np.argmax(profits)]
optimal_profit = max(profits)

print(f"Corner Points: {corner_points}")
print(f"Profits at Corner Points: {profits}")
print(f"Optimal Solution: {optimal_point} with Profit = {optimal_profit}")
# Out:
# Corner Points: [(0, 0), (0, 4), (2, 3), (4, 0)]
# Profits at Corner Points: [0, 12, 19, 20]
# Optimal Solution: (4, 0) with Profit = 20

# %% [markdown]
# # NUMBER 7: Minimizing Cost for a Transport Company
# A transport company operates two types of vehicles, X and Y, to transport goods.
# Vehicle X requires 3 hours of fuel and 2 hours of driver time for each trip, while vehicle
# Y requires 4 hours of fuel and 1 hour of driver time for each trip. The company has a
# budget that allows for 18 hours of fuel and 10 hours of driver time. The cost of using
# vehicle X is $6 per trip, and the cost of using vehicle Y is $7 per trip. Minimize the total
# cost.

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
MINIMIZE 
    Z = 6x + 7y
SUBJECT TO
    3x + 4y ≤ 18  (Fuel hours)
    2x + y ≤ 10   (Driver hours)
    x ≥ 0, y ≥ 0  (Non-negativity)
"""

# Create values for x
x = np.linspace(0, 10, 400)

# Constraints: solving for y in terms of x
y1 = (18 - 3 * x) / 4  # From 3x + 4y ≤ 18
y2 = 10 - 2 * x        # From 2x + y ≤ 10

# Ensure y values are non-negative
y1 = np.clip(y1, 0, None)
y2 = np.clip(y2, 0, None)

# Plot constraints
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label='3x + 4y ≤ 18')
plt.plot(x, y2, label='2x + y ≤ 10')

# Shade the feasible region
plt.fill_between(x, np.minimum(y1, y2), 0, color='red', alpha=0.3, label='Feasible Region')

# Add labels, grid, and legend
plt.xlim(0, 6)
plt.ylim(0, 6)
plt.xlabel('Vehicle X (x)')
plt.ylabel('Vehicle Y (y)')
plt.title('Feasible Region and Objective Function')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()

# Objective function Z = 6x + 7y
for z in [30, 45, 60]:
    plt.plot(x, (z - 6 * x) / 7, linestyle='--', label=f'Z={z}')

plt.legend()
plt.show()

# Calculate corner points manually
corner_points = [(0, 0), (0, 4.5), (2, 6), (6, 0)]  # Intersections and boundary points
costs = [6 * x + 7 * y for x, y in corner_points]

# Find the optimal point and cost
optimal_point = corner_points[np.argmin(costs)]
optimal_cost = min(costs)

print(f"Corner Points: {corner_points}")
print(f"Costs at Corner Points: {costs}")
print(f"Optimal Solution: {optimal_point} with Cost = {optimal_cost}")
# Out:
# Corner Points: [(0, 0), (0, 4.5), (2, 6), (6, 0)]
# Costs at Corner Points: [0, 31.5, 54, 36]
# Optimal Solution: (0, 0) with Cost = 0

# %% [markdown]
# # NUMBER 8. Maximizing Revenue from Two Products
# A company manufactures two types of products, P1 and P2, and sells them at different
# prices. Product P1 requires 4 hours of labor, 1 unit of raw material, and 3 units of
# machine time to produce. Product P2 requires 3 hours of labor, 2 units of raw material,
# and 2 units of machine time. The company has 30 hours of labor, 18 units of raw
# material, and 24 units of machine time available. The revenue from selling each unit of
# P1 is $10, and the revenue from selling each unit of P2 is $12.

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE 
    Z = 10x + 12y
SUBJECT TO
    4x + 3y ≤ 30  (Labor hours)
    x + 2y ≤ 18   (Raw material)
    3x + 2y ≤ 24  (Machine time)
    x ≥ 0, y ≥ 0  (Non-negativity)
"""

# Create values for x
x = np.linspace(0, 10, 400)

# Constraints: solving for y in terms of x
y1 = (30 - 4 * x) / 3  # From 4x + 3y ≤ 30
y2 = (18 - x) / 2      # From x + 2y ≤ 18
y3 = (24 - 3 * x) / 2  # From 3x + 2y ≤ 24

# Ensure y values are non-negative
y1 = np.clip(y1, 0, None)
y2 = np.clip(y2, 0, None)
y3 = np.clip(y3, 0, None)

# Plot constraints
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label='4x + 3y ≤ 30')
plt.plot(x, y2, label='x + 2y ≤ 18')
plt.plot(x, y3, label='3x + 2y ≤ 24')

# Shade the feasible region
plt.fill_between(x, np.minimum(np.minimum(y1, y2), y3), 0, color='red', alpha=0.3, label='Feasible Region')

# Add labels, grid, and legend
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.xlabel('Product P1 (x)')
plt.ylabel('Product P2 (y)')
plt.title('Feasible Region and Objective Function')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()

#Objective function Z = 10x + 12y
for z in [60, 90, 120]:
    plt.plot(x, (z - 10 * x) / 12, linestyle='--', label=f'Z={z}')

plt.legend()
plt.show()

# Calculate corner points manually
corner_points = [(0, 0), (0, 9), (3, 7.5), (6, 6), (6, 0)]  # Intersections and boundary points
revenues = [10 * x + 12 * y for x, y in corner_points]

# Find the optimal point and revenue
optimal_point = corner_points[np.argmax(revenues)]
optimal_revenue = max(revenues)

print(f"Corner Points: {corner_points}")
print(f"Revenues at Corner Points: {revenues}")
print(f"Optimal Solution: {optimal_point} with Revenue = {optimal_revenue}")
# Out:
# Corner Points: [(0, 0), (0, 9), (3, 7.5), (6, 6), (6, 0)]
# Revenues at Corner Points: [0, 108, 120.0, 132, 60]
# Optimal Solution: (6, 6) with Revenue = 132

# %% [markdown]
# # NUMBER 9: Advertising Campaign Budget Allocation
# A company runs two advertising campaigns, A and B, using a budget allocated for
# television, print media, and social media. The company has a total of $10,000 to allocate
# across these campaigns, with the following constraints: Campaign A requires $4,000 for
# television, $2,000 for print media, and $1,000 for social media. Campaign B requires $3,000
# for television, $2,500 for print media, and $1,500 for social media. The company can spend
# no more than $5,000 on television, $4,500 on print media, and $3,000 on social media.
# The company wants to maximize the reach of the campaigns, where: The reach of
# campaign A is 500,000 people. The reach of campaign BBB is 400,000 people. Maximize
# the total reach.

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE 
    Z = 500x + 400y
SUBJECT TO
    4x + 3y ≤ 5  (Television budget, in thousands)
    2x + 2.5y ≤ 4.5  (Print media budget, in thousands)
    x + 1.5y ≤ 3  (Social media budget, in thousands)
    x ≥ 0, y ≥ 0  (Non-negativity)
"""

# Create values for x
x = np.linspace(0, 5, 400)

# Constraints: solving for y in terms of x
y1 = (5 - 4 * x) / 3      # From 4x + 3y ≤ 5
y2 = (4.5 - 2 * x) / 2.5  # From 2x + 2.5y ≤ 4.5
y3 = (3 - x) / 1.5        # From x + 1.5y ≤ 3

# Ensure y values are non-negative
y1 = np.clip(y1, 0, None)
y2 = np.clip(y2, 0, None)
y3 = np.clip(y3, 0, None)

# Plot constraints
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label='4x + 3y ≤ 5')
plt.plot(x, y2, label='2x + 2.5y ≤ 4.5')
plt.plot(x, y3, label='x + 1.5y ≤ 3')

# Shade the feasible region
plt.fill_between(x, np.minimum(np.minimum(y1, y2), y3), 0, color='red', alpha=0.3, label='Feasible Region')

# Add labels, grid, and legend
plt.xlim(0, 5)
plt.ylim(0, 5)
plt.xlabel('Campaign A (x)')
plt.ylabel('Campaign B (y)')
plt.title('Feasible Region and Objective Function')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()

# Objective function Z = 500x + 400y
for z in [1000, 1500, 2000]:
    plt.plot(x, (z - 500 * x) / 400, linestyle='--', label=f'Z={z} (thousands)')

plt.legend()
plt.show()

# Calculate corner points manually
corner_points = [(0, 0), (0, 2), (0.9, 1.4), (1.5, 1), (2.5, 0)]  # Intersections and boundary points
reaches = [500 * x + 400 * y for x, y in corner_points]

# Find the optimal point and maximum reach
optimal_point = corner_points[np.argmax(reaches)]
max_reach = max(reaches)

print(f"Corner Points: {corner_points}")
print(f"Reach at Corner Points: {reaches}")
print(f"Optimal Solution: {optimal_point} with Maximum Reach = {max_reach} thousand people")

# %% [markdown]
# # NUMBER 10: Meal Planning for a School Cafeteria
# A school cafeteria wants to plan a meal schedule for the week, offering two types of meals,
# A and B. Each type of meal requires certain ingredients, and the cafeteria has limited
# resources. Meal A requires 2 units of meat, 3 units of vegetables, and 1 unit of rice. Meal B
# requires 4 units of meat, 2 units of vegetables, and 2 units of rice. The cafeteria has a total
# of 30 units of meat, 24 units of vegetables, and 20 units of rice available for the week. The
# cafeteria earns $6 from each meal A and $5 from each meal B. Maximize the total revenue.

# %%
import numpy as np
import matplotlib.pyplot as plt

"""
MAXIMIZE
    Z = 6x + 5y
SUBJECT TO
    2x + 4y ≤ 30  (Meat constraint)
    3x + 2y ≤ 24  (Vegetable constraint)
    x + 2y ≤ 20   (Rice constraint)
    x ≥ 0, y ≥ 0  (Non-negativity constraints)
"""

# Define values for x
x = np.linspace(0, 20, 400)

# Constraints: solving for y in terms of x
y1 = (30 - 2 * x) / 4      # From 2x + 4y ≤ 30
y2 = (24 - 3 * x) / 2      # From 3x + 2y ≤ 24
y3 = (20 - x) / 2          # From x + 2y ≤ 20

# Ensure y values are non-negative
y1 = np.clip(y1, 0, None)
y2 = np.clip(y2, 0, None)
y3 = np.clip(y3, 0, None)

# Plot constraints
plt.figure(figsize=(8, 6))
plt.plot(x, y1, label='2x + 4y ≤ 30 (Meat)')
plt.plot(x, y2, label='3x + 2y ≤ 24 (Vegetables)')
plt.plot(x, y3, label='x + 2y ≤ 20 (Rice)')

# Shade the feasible region
plt.fill_between(x, np.minimum(np.minimum(y1, y2), y3), 0, color='red', alpha=0.3, label='Feasible Region')

# Add labels, grid, and legend
plt.xlim(0, 10)
plt.ylim(0, 10)
plt.xlabel('Meal A (x)')
plt.ylabel('Meal B (y)')
plt.title('Feasible Region and Objective Function')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()

# Plot sample levels of the objective function Z = 6x + 5y
for z in [50, 80, 100]:
    plt.plot(x, (z - 6 * x) / 5, linestyle='--', label=f'Z={z}')

plt.legend()
plt.show()

# Calculate corner points manually
corner_points = [
    (0, 0),                       # Intersection of non-negativity constraints
    (0, 7.5),                     # y-axis intercept of 2x + 4y ≤ 30
    (6, 6),                       # Intersection of 2x + 4y ≤ 30 and 3x + 2y ≤ 24
    (8, 3),                       # Intersection of 3x + 2y ≤ 24 and x + 2y ≤ 20
    (10, 0)                       # x-axis intercept of x + 2y ≤ 20
]

# Calculate revenue (Z = 6x + 5y) at each corner point
revenues = [6 * x + 5 * y for x, y in corner_points]

# Find the optimal solution
optimal_point = corner_points[np.argmax(revenues)]
max_revenue = max(revenues)

print(f"Corner Points: {corner_points}")
print(f"Revenue at Corner Points: {revenues}")
print(f"Optimal Solution: {optimal_point} with Maximum Revenue = ${max_revenue}")
# Out:
# Corner Points: [(0, 0), (0, 7.5), (6, 6), (8, 3), (10, 0)]
# Revenue at Corner Points: [0, 37.5, 66, 63, 60]
# Optimal Solution: (6, 6) with Maximum Revenue = $66
